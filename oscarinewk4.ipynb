# %%
import pandas as pd

# %%
import pandas as pd
#loading the csv file
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")

data.head(15)
# Out:
#             Destinations  Score_out_of_10  Average_ hotel_rating  \
# 0              Indonesia              7.5                    3.0
# 1               Thailand              9.5                    3.0
# 2   United Arab Emirates              8.2                    4.5
# 3                  China              6.2                    3.0
# 4               Malaysia              6.9                    3.0
# 5                 Turkey              5.9                    4.0
# 6                England              7.3                    4.5
# 7           Saudi Arabia              6.5                    4.0
# 8                  Spain              8.2                    4.0
# 9                  Italy              6.3                    3.9
# 10                   USA              7.9                    3.8
# 11                 Japan              8.3                    3.5
# 12                France              8.9                    4.3
# ...

# %%
import pandas as pd
#number of rows and columns in the file
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")

data.shape
# Out:
# (15, 5)

# %%
import pandas as pd
#printing row 3-8 using iloc/loc
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
data.iloc[3:8]
# Out:
#    Destinations  Score_out_of_10  Average_ hotel_rating  All_inclusive_hotels  \
# 3         China              6.2                    3.0                   500
# 4      Malaysia              6.9                    3.0                   230
# 5        Turkey              5.9                    4.0                   241
# 6       England              7.3                    4.5                    51
# 7  Saudi Arabia              6.5                    4.0                    31
#
#   Most-visited_city
# 3          Hongkong
# 4      Kuala Lumpur
# 5          Istanbul
# 6            London
# 7            Makkah

# %%
import pandas as pd
#Find the mean number of all-inclusive hotels across all destinations.

data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
print(data["All_inclusive_hotels"].mean())
# Out:
# 260.53333333333336

# %%
import pandas as pd
#Find the lowest scoring destination
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
print(data["Destinations"].min())
# Out:
# China

# %%
import pandas as pd
#Find the highest scoring destination
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")

print(data["Destinations"].max())
# Out:
# United Arab Emirates

# %%
import pandas as pd
#Find all the destinations where there are more than 9 all-inclusive hotels
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
myfilter = data["All_inclusive_hotels"] > 9
myfilter
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# Name: All_inclusive_hotels, dtype: bool

# %%
import pandas as pd
#Filter the data by score above 8.
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
myfilter = data["Score_out_of_10"] > 8
print(myfilter)
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# Name: Score_out_of_10, dtype: bool

# %%
import pandas as pd
#Filter the data score below 2 ( I need to know if these destinations should be removed or there is a problem)
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
myfilter = data["Score-out_of_10"] < 2

print("this gives me an error message because there is not a score below 2")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Score-out_of_10'
#
# ...

# %%
import pandas as pd
#Is there a correlation between number of all-inclusive hotels and score?
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
print(data["All_inclusive_hotels"].corr(data["Score_out_of_10"]))
# Out:
# 0.31603884903749824

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#Create a data visualisation diagram to show destination and highest scores?
data = pd.read_csv(r"/Users/oscarine/TA/Destinations - Sheet1.csv")
data.plot(y="Score_out_of_10", x="Destinations")
# Out:
# <AxesSubplot:xlabel='Destinations'>
